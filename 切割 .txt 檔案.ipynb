# %% [markdown]
# Python使用open()打開檔案<br>
# `f = open('檔案', '模式')`
# 模式有
#
# r - 讀取(檔案需存在)
#
# w - 新建檔案寫入(檔案可不存在，若存在則清空)
#
# a - 資料附加到舊檔案後面(游標指在EOF)
#
# r+ - 讀取舊資料並寫入(檔案需存在且游標指在開頭)
#
# w+ - 清空檔案內容，新寫入的東西可在讀出(檔案可不存在，會自行新增)
#
# a+ - 資料附加到舊檔案後面(游標指在EOF)，可讀取資料
#
# b - 二進位模式

# %%
import sys
results = []
with open('result.txt','r') as f:
    for line in f:
        results.append(list(line.strip(' \ ').split(' ')[0]))
print(results)
# Out:
# [['這', '群', '人'], ['【', 'J', 'o', 'e', 'm', 'a', 'n', '】', '在', '飛', '機', '上', '吃', '烤', '鰻', '魚', '！', '中', '國', '東', '方', '航', '空', '商', '務', '艙', '體', '驗'], ['民', '雄', '鬼', '屋', '神', '算', '(', '下', ')', '靈', '體', '入', '侵', '夜', '半', '傳', '功', '《', '台', '灣', '大', '代', '誌', '》', '2', '0', '1', '9', '0', '9', '0', '1', '\n'], ['2', '0', '0', '萬', '讓', '你', '花', '到', '爽', '，', '輸', '家', '只', '能', '做', '牛', '做', '馬', '！', '寫', '真', '女', '星', '素', '顏', '美', '不', '美', '？', '睡', '覺', '突', '襲', '，', '讓', '你', '看', '見', '藝', '人', '最', '真', '實', '，', '最', '無', '厘', '頭', '的', '一', '面', '！', '綜', '藝', '玩', '很', '大', '【', '第', '1', '3', '2', '回'], ['#', '2', '3', '【', '谷', '阿', '莫', 'L', 'i', 'f', 'e', '】', '你', '猜', '胸', '口', '碎', '大', '石', '難', '不', '難', '\n'], ['天', '道', '盟', '吳', '桐', '潭', '7', '0', '壽', '宴', '\u3000', '海', '內', '外', '幫', '派', '大', '老', '齊', '聚', '｜', '三', '立', '新', '聞', '台', '\n'], ['【', '狠', '愛', '演', '】', '星', '空', '酒', '！', '喝', '下', '整', '個', '銀', '河', '系', '『', '派', '對', '神', '器', '』', '\n'], ['【', 'L', 'i', 'f', 'e', '週', '記', '】', '#', '4', '7'], ['把', '一', '隻', '蝙', '蝠', '和', '蟑', '螂', '關', '在', '封', '閉', '空', '間', '裡', '，', '會', '發', '生', '什', '麼', '？', '\n'], ['大', '時', '代'], ['為', '了', '兒', '子', '，', '迎', '接', '第', '三', '隻', '小', '野', '貓', '『', '撿', '到', '吃', '貨', '？', '』', '\n'], ['男', '生', '小', '心', '！', '如', '何', '破', '解', '一', '輩', '子', '工', '具', '人', '的', '命', '運', '？', '｜', '愛', '莉', '莎', '莎', 'A', 'l', 'i', 's', 'a', 's', 'a', '\n'], ['【', '央', '視', '一', '分', '鐘', '】', '韓', '國', '瑜', '憂', '國', '民', '黨', '腦', '袋', '進', '水'], ['2', '0', '1', '9', '-', '0', '9', '-', '0', '4', '【', 'P', 'O', 'P', '撞', '新', '聞', '】', '黃', '暐', '瀚', '談', '：', '「', '高', '鐵', '撿', '到', '3', '0', '0', '萬', '！', '」', '\n'], ['【', '聲', '林', '之', '王', '2', '】', 'E', 'P', '2', '完', '整', '版'], ['假', '借', '大', '胃', '王', '名', '義', '壓', '榨', '實', '習', '生', '？', '胖', '子', '到', '底', '吃', '不', '吃', '得', '贏', '瘦', '子', '【', '滑', '挑', '戰', '#', '8', '1', '】', '\n'], ['反', '骨', '違', '禁', '品', '大', '公', '開', '!', '!', '!', '團', '員', '們', '都', '帶', '了', '什', '麼', '違', '禁', '品', '?', '!'], ['獨', '！', '藍', '「', '瑜', '下', '郭', '上', '」', '燒', '不', '停', '？', '2', '0', '2', '0', '這', '局', '買', '「', '雙', '保', '險', '」', '？', '【', '新', '聞', '面', '對', '面', '】', '1', '9', '0', '9', '0', '3', '\n'], ['【', '娛', '樂', '百', '分', '百', '】', '2', '0', '1', '9', '.', '0', '9', '.', '0', '2', '《', '凹', '嗚', '狼', '人', '殺', '》', '小', '豬', '、', '愷', '樂', '│', '孫', '生', '、', '小', '賴', '、', '斯', '亞', '、', '邱', '鋒', '澤', '、', '愷', '愷', '、', '篠', '崎', '泫', '、', '駱', '儀', '如', '、', '陳', '政', '倫', '\n'], ['【', '0', '9', '0', '1', '】', '卡', '提', '諾', '狂', '新', '聞'], ['【', '炮', '仔', '聲', '】', 'E', 'P', '1', '7', '6'], ['炮', '仔', '聲'], ['老', '鵝', '特', '搜', '#', '1', '7', '9'], ['喪', '屍', '腦', '中', '長', '出', '真', '菌', '植', '物', '，', '聚', '成', '了', '參', '天', '大', '樹', '，', '成', '熟', '後', '人', '類', '便', '會', '滅', '絕', '！', '\n'], ['陳', '明', '文', '掉', '3', '0', '0', '萬', '駁', '斥', '政', '治', '獻', '金', '說', '！', '公', '機', '關', '也', '打', '韓', '？', '行', '政', '中', '立', '呢', '《', '#', '直', '播', '線', '上', '》', '2', '0', '1', '9', '.', '0', '9', '.', '0', '4'], ['2', '0', '1', '9', '0', '9', '0', '2'], ['【', '完', '整', '版', '】', '這', '些', '爸', '爸', '都', '是', '女', '兒', '控'], ['H', 'o', 'w', 'F', 'u', 'n'], ['大', '胃', '王', '挑', '戰', '清', '空', '超', '市', '火', '鍋', '！', '和', '牛', '龍', '蝦', '吃', '爽', '爽', '！', 'f', 't', '.', '都', '給', '涵', '涵', '吃', '丨', 'M', 'U', 'K', 'B', 'A', 'N', 'G'], ['電', '話', '惡', '整', '！', '如', '果', '假', '裝', '跟', '朋', '友', '有', '約', '要', '他', '到', '指', '定', '地', '點', '，', '誰', '會', '來', '？', 'F', 't', '.', '阿', '滴', '英', '文', '.', '含', '羞', '草', '.', 'E', 'C', 'H', 'O', '【', '聖', '結', '石', 'S', 'a', 'i', 'n', 't', '】', '\n'], ['嚇', '！', '遺', '忘', '在', '高', '鐵', '上', '的', '登', '機', '箱', '藏', '3', '0', '0', '萬', '現', '鈔'], ['陸', '攻', '台', '最', '近', '橋', '頭', '堡', '！'], ['这', '部', '电', '影', '告', '诉', '我', '们', '，', '程', '序', '员', '果', '然', '能', '改', '变', '世', '界', ' ...
