# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
name = raw_input ("What is your name?")

number = 0
while number < 10:
    print ("Hello" + name + "merry christmas")
    number = number + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4a3f8c8c4de9> in <module>
# ----> 1 name = raw_input ("What is your name?")
#       2
#       3 number = 0
#       4 while number < 10:
#       5     print ("Hello" + name + "merry christmas")
#
# NameError: name 'raw_input' is not defined

# %%
plot([-2,3,-5,4,9,1])

# %%
randn(10)
# Out:
# array([ 1.08345295, -0.34478955, -0.33366621, -1.15787454,  1.71491489,
#        -0.77727904,  1.66972234,  2.30906166, -0.16776673, -0.93979952])

# %%
plot(randn(100))

# %%
plot([-2, 1, 2.7, 3.3] , [3, -5, 6, 0])
